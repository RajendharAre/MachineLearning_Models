# %% [markdown]
# ### Linear Regression Model

# %% [markdown]
# ##### Importing Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([2,3,4,5,6,7,8,9,10])
y = np.array([5,6,7,8,9,10,12,11,14])
x_mean = np.mean(x)
y_mean = np.mean(y)
sxy =  np.sum((x - x_mean) * (y - y_mean))
sxx =  np.sum((x - x_mean) ** 2)
m = sxy / sxx
b = y_mean - m * x_mean
print(f"m: {m}, b: {b}")

y_pred = m * x + b
sse = np.sqrt(np.sum((y - y_pred) ** 2) / (len(x) - 2))
mse = sse / np.sqrt(np.sum((x - x_mean) ** 2))
ssr = np.sum((y_pred - y_mean) ** 2)
sst = np.sum((y - y_mean) ** 2)
r2 = ssr / sst
print(f"mse: {mse}, sse: {sse}, r2: {r2}")
plt.scatter(x, y, label='Data Points')
plt.plot(x, y_pred, color='red', label='Regression Line')   
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression')
plt.legend()
plt.show()
# Out:
# m: 1.05, b: 2.81111111111111
# mse: 0.08075372450335667, sse: 0.6255156602914445, r2: 0.960241935483871
